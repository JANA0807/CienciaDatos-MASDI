# %% [markdown]
# <a href="https://colab.research.google.com/github/JANA0807/CienciaDatos-MASDI/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6803cf03-a941-468a-8fcb-35819d8efafc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6803cf03-a941-468a-8fcb-35819d8efafc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded
# Out:
# {'Base Contratos.csv': b'\xef\xbb\xbfGenero;Tipo de credito;Producto de credito;Plazo de credito;Tasa; Montos desembolsados ;Tipo de tasa;Clase de deudor;Edad;;;\r\nFemenino;Consumo;Libre Inversion;Mas de 3 a\xc3\xb1os y hasta 5 a\xc3\xb1os;17,6; 1.000.000 ;Tasa Fija;Antiguo;37;;;\r\nFemenino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;17,6; 1.000.000 ;Tasa Fija;Antiguo;36;;;\r\nFemenino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;18,52; 1.000.000 ;Tasa Fija;Antiguo;37;;;\r\nMasculino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;18,52; 1.000.000 ;Tasa Fija;Antiguo;56;;;\r\nMasculino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;18,52; 1.000.000 ;Tasa Fija;Antiguo;40;;;\r\nFemenino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;18,61; 1.000.000 ;Tasa Fija;Antiguo;33;;;\r\nMasculino;Consumo;Libre Inversion;Mas de 1 a\xc3\xb1o y hasta 3 a\xc3\xb1os;18,61; 1.000.000 ;Tasa Fija;Antiguo;
# ...

# %%
import pandas as pd
import io

# %%
dataframe=pd.read_csv(io.StringIO(uploaded['Base Contratos.csv'].decode('utf-8')))

# %%
dataframe
# Out:
#                                                    Genero;Tipo de credito;Producto de credito;Plazo de credito;Tasa; Montos desembolsados ;Tipo de tasa;Clase de deudor;Edad;;;
# Femenino;Consumo;Libre Inversion;Mas de 3 años ...              6; 1.000.000 ;Tasa Fija;Antiguo;37;;;
# Femenino;Consumo;Libre Inversion;Mas de 1 año y...              6; 1.000.000 ;Tasa Fija;Antiguo;36;;;
# Femenino;Consumo;Libre Inversion;Mas de 1 año y...             52; 1.000.000 ;Tasa Fija;Antiguo;37;;;
# Masculino;Consumo;Libre Inversion;Mas de 1 año ...             52; 1.000.000 ;Tasa Fija;Antiguo;56;;;
# Masculino;Consumo;Libre Inversion;Mas de 1 año ...             52; 1.000.000 ;Tasa Fija;Antiguo;40;;;
# ...                                                                                               ...
# Femenino;Hipotecario;Vivienda No Vis pesos;De 7...             73; 444.000.000 ;Tasa Fija;Nuevo;49;;;
# ...

# %%
dataframe.head()
# Out:
#                                                    Genero;Tipo de credito;Producto de credito;Plazo de credito;Tasa; Montos desembolsados ;Tipo de tasa;Clase de deudor;Edad;;;
# Femenino;Consumo;Libre Inversion;Mas de 3 años ...              6; 1.000.000 ;Tasa Fija;Antiguo;37;;;
# Femenino;Consumo;Libre Inversion;Mas de 1 año y...              6; 1.000.000 ;Tasa Fija;Antiguo;36;;;
# Femenino;Consumo;Libre Inversion;Mas de 1 año y...             52; 1.000.000 ;Tasa Fija;Antiguo;37;;;
# Masculino;Consumo;Libre Inversion;Mas de 1 año ...             52; 1.000.000 ;Tasa Fija;Antiguo;56;;;
# Masculino;Consumo;Libre Inversion;Mas de 1 año ...             52; 1.000.000 ;Tasa Fija;Antiguo;40;;;
